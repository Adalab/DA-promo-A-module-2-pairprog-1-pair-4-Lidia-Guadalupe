# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Cargad el csv que guardasteis ayer.
#
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio. En las próximas sesiones lo iremos limpiando. Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame.
#
# Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios.

# %%
df_attack2 = pd.read_csv('./attack2.csv')
df_attack2.head()

df_null= df_attack2.dropna(inplace = True)
#pd.options.display.max_columns = None

# %%
df_null= df_attack2.dropna(inplace = True)
df_attack2
# Out:
#       Unnamed: 0  unnamed: 0   case number    year        type       country  \
# 0              0           0    2018.06.25  2018.0     Boating           USA
# 6              6           6  2018.06.03.a  2018.0  Unprovoked        BRAZIL
# 8              8           8  2018.05.26.b  2018.0  Unprovoked           USA
# 10            10          10    2018.05.24  2018.0    Provoked     AUSTRALIA
# 13            13          13  2018.05.13.a  2018.0     Invalid       ENGLAND
# ...          ...         ...           ...     ...         ...           ...
# 5528        5528        5545    1901.07.30  1901.0  Unprovoked  SOUTH AFRICA
# 5631        5631        5648    1894.11.28  1894.0  Unprovoked     AUSTRALIA
# 5667        5667        5684    1892.03.02  1892.0    Provoked     AUSTRALIA
# 5797        5797        5814    1880.11.25  1880.0  Unprovoked     AUSTRALIA
# 5905        5905        5922    1868.05.13  1868.0  Unprovoked         INDIA
#
# ...

# %%
pd.options.display.max_columns = None
df_attack2.head(5)
# Out:
#     Unnamed: 0  unnamed: 0   case number    year        type    country  \
# 0            0           0    2018.06.25  2018.0     Boating        USA
# 6            6           6  2018.06.03.a  2018.0  Unprovoked     BRAZIL
# 8            8           8  2018.05.26.b  2018.0  Unprovoked        USA
# 10          10          10    2018.05.24  2018.0    Provoked  AUSTRALIA
# 13          13          13  2018.05.13.a  2018.0     Invalid    ENGLAND
#
#           area                      location        activity  \
# 0   California   Oceanside, San Diego County        Paddling
# 6   Pernambuco         Piedade Beach, Recife        Swimming
# 8      Florida  Cocoa Beach, Brevard  County         Walking
# 10  Queensland               Cairns Aquarium  Feeding sharks
# 13    Cornwall                Off Land's End         Fishing
#
#                       name sex  age            time          species   \
# 0              Julie Wolfe    F  57           18h00       White shark
# ...

# %% [markdown]
# 2. **¿Cuál es el número de ataques que se han producido en Estados Unidos?**

# %%
attackusa = df_attack2[df_attack2['country'] == 'USA']
attackusa.head()
# Out:
#     Unnamed: 0  unnamed: 0   case number    year        type country  \
# 0            0           0    2018.06.25  2018.0     Boating     USA
# 8            8           8  2018.05.26.b  2018.0  Unprovoked     USA
# 35          35          35    2018.03.31  2018.0  Unprovoked     USA
# 53          53          53    2017.12.31  2017.0  Unprovoked     USA
# 60          60          60    2017.11.24  2017.0  Unprovoked     USA
#
#           area                          location                 activity  \
# 0   California       Oceanside, San Diego County                 Paddling
# 8      Florida      Cocoa Beach, Brevard  County                  Walking
# 35      Hawaii                       Kukio Beach  Stand-Up Paddleboarding
# 53      Hawaii              Hultin's Beach, Oahu                  Surfing
# 60  California  Stillwater Cove, Monterey County             Spearfishing
#
#                 name sex  age   time            species   \
# ...

# %% [markdown]
# 3. **¿Y en España?**
#
# 3.1 ¿En qué regiones se han producido los ataques?
#
# 3.2 ¿Cuántos ataques se han producido en cada área?

# %%
attackspain = df_attack2[df_attack2['country'] == 'SPAIN']
attackspain["area"].unique()
attackspain["area"].value_counts()
#attackspain = df_attack2[df_attack2["country"].isin(["Doctor", "Master"] )]
#attackspain.head()
# Out:
# Castellón              1
# Alicante Province      1
# Alicante               1
# Grand Canary Island    1
# Costa Blanca           1
# Name: area, dtype: int64

# %%
attackspain2 = df_attack2[df_attack2['country'] == 'SPAIN'] #Pensar como hacerlo

# %% [markdown]
# 4.  **Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.** 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin().
# Hacedlo con ambas herramientas.
#
# 4.1 ¿Cuántos ataques se han producido en cada pais?
#
# 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?
#
# 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?
#
# 4.4 ¿Y después del 2000?

# %%
attack34 = df_attack2[((df_attack2['country'] == 'USA')) | ((df_attack2['country'] == 'AUSTRALIA'))]
attack34

# %%
attack3 = df_attack2[df_attack2["country"].isin(["USA" , "AUSTRALIA"])]
attack3.head()
attack3["country"].value_counts()
# Out:
# USA          719
# AUSTRALIA    324
# Name: country, dtype: int64

# %%
attack4 = df_attack2[((df_attack2['country'] == 'AUSTRALIA')) & ((df_attack2['activity'] == 'Paddling'))]
attack4
#En Australia no juegan a eso
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, unnamed: 0, case number, year, type, country, area, location, activity, name, sex , age, time, species , href]
# Index: []

# %% [markdown]
# 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
attack5 = df_attack2[((df_attack2['country'] == 'AUSTRALIA')) & ((df_attack2['year'] < 2000))]
attack5.head()
attack5["year"].value_counts()
# Out:
# 1961.0    9
# 1959.0    6
# 1960.0    5
# 1989.0    5
# 1963.0    5
#          ..
# 1947.0    1
# 1965.0    1
# 1952.0    1
# 1953.0    1
# 1880.0    1
# Name: year, Length: 66, dtype: int64

# %% [markdown]
# 4.4 ¿Y después del 2000?

# %%
attack6 = df_attack2[((df_attack2['country'] == 'AUSTRALIA')) & ((df_attack2['year'] > 2000))]  #¿Que pasa con el 2000? ¿Por que nadie le quiere? T_T
attack6.head()
attack6["year"].value_counts()
# Out:
# 2012.0    17
# 2015.0    14
# 2009.0    13
# 2011.0    12
# 2007.0    12
# 2016.0    11
# 2014.0    10
# 2008.0    10
# 2005.0     9
# 2017.0     9
# 2006.0     9
# 2013.0     8
# 2004.0     7
# 2018.0     7
# 2010.0     7
# 2002.0     5
# 2003.0     4
# 2001.0     3
# Name: year, dtype: int64

# %% [markdown]
# 5. **Extraed unicamente los ataques a mujeres.**

# %%
attackgirls= df_attack2[df_attack2['sex '] == 'F']
attackgirls
# Out:
#       Unnamed: 0  unnamed: 0   case number    year        type       country  \
# 0              0           0    2018.06.25  2018.0     Boating           USA
# 40            40          40    2018.02.23  2018.0  Unprovoked     AUSTRALIA
# 53            53          53    2017.12.31  2017.0  Unprovoked           USA
# 71            71          71    2017.10.22  2017.0  Unprovoked     AUSTRALIA
# 75            75          75    2017.10.05  2017.0  Unprovoked           USA
# ...          ...         ...           ...     ...         ...           ...
# 4151        4151        4163    1958.04.05  1958.0  Unprovoked  SOUTH AFRICA
# 4170        4170        4182    1957.12.30  1957.0  Unprovoked  SOUTH AFRICA
# 4678        4678        4690    1942.12.26  1942.0  Unprovoked     AUSTRALIA
# 4706        4706        4718    1942.01.04  1942.0  Unprovoked     AUSTRALIA
# 4913        4913        4925  1934.12.31.b  1934.0  Unprovoked     AUSTRALIA
#
# ...
