# %% [markdown]
# **Cargar el dataset**
#
# **💡 Pista Si hacemos la carga del dataset sin el parámetro encoding nos dará error. Aquí tenéis una lista de los encodings disponibles en pandas. Buscad por los encoding de tipo ISO.**

# %%
import pandas as pd

# %% [markdown]
# **2. Haced una exploración básica del dataframe:**

# %% [markdown]
# - **Cuántas filas y columnas tiene el dataframe**
# ## 5rows x 22 columns

# %% [markdown]
# - **Mostrad las primeras cinco filas  del dataframe**

# %%
df = pd.read_csv("./attacks.csv", index_col=0)
df.head()
# Out:
#   Case Number    Year        Type    Country             Area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#    ...         Species           Investigator or Source  \
# 0  ...      White shark                R. Collier, GSAF
# 1  ...              NaN  K.McMurray, TrackingSharks.com
# 2  ...              NaN  K.McMurray, TrackingSharks.com
# 3  ...        2 m shark                  B. Myatt, GSAF
# 4  ...  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order  Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0          NaN         NaN
# 1    2018.06.18         6302.0          NaN         NaN
# 2    2018.06.09         6301.0          NaN         NaN
# 3    2018.06.08         6300.0          NaN         NaN
# 4    2018.06.04         6299.0          NaN         NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# - **Mostrad las ultimas cinco filas del dataframe**

# %%
df.tail()
# Out:
#        Case Number    Year          Type    Country               Area  \
# 6127  1804.02.26.R  1804.0          Boat  AUSTRALIA    New South Wales
# 6128    1803.05.17  1803.0  Sea Disaster        USA     South Carolina
# 6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA  Western Australia
# 6130  1802.04.13.R  1802.0    Unprovoked      INDIA                NaN
# 6131  1801.12.18.R  1801.0      Provoked        NaN                NaN
#
#                               Location                         Activity  \
# 6127    Georges Head, off Port Jackson                              NaN
# 6128                    Off Charleston                              NaN
# 6129  Hamelin Harbour, at Faure Island                              NaN
# 6130                               NaN                              NaN
# 6131                               NaN  Standing on landed shark's tail
#
#                                  Name Sex   Age  ...   Species   \
# 6127                             boat  NaN  NaN  ...        NaN
# 6128                    Captain Jones    M  NaN  ...        NaN
# 6129  M. Lefevre & a sailor (rescuer)    M  NaN  ...        NaN
# 6130                              NaN  NaN  NaN  ...        NaN
# 6131                 Stephen Pettigew    N  NaN  ...  12' shark
#
#                                  Investigator or Source  \
# 6127                         Sydney Gazette, 2/26/1804
# 6128                            Evening Post, 6/13/1803
# 6129  F.  Peron ref in G.P. Whitley (Fishes of Austr...
# 6130                  Evening Post (New York) 4/13/1802
# 6131                       The Evening Post, 12/18/1801
#
#                                   pdf  \
# 6127  1804.02.26-boat-GeorgesHead.pdf
# 6128             1803.05.17-Jones.pdf
# 6129           1803.03.00-Lefevre.pdf
# 6130           1802.04.13.R-India.pdf
# 6131       1801.12.18.R-Pettigrew.pdf
#
#                                            href formula  \
# 6127  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6128  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6129  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6130  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6131  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 6127  http://sharkattackfile.net/spreadsheets/pdf_di...  1804.02.26.R
# 6128  http://sharkattackfile.net/spreadsheets/pdf_di...    1803.05.17
# 6129  http://sharkattackfile.net/spreadsheets/pdf_di...    1803.03.00
# 6130  http://sharkattackfile.net/spreadsheets/pdf_di...  1802.04.13.R
# 6131  http://sharkattackfile.net/spreadsheets/pdf_di...  1801.12.18.R
#
#      Case Number.2 original order  Unnamed: 22 Unnamed: 23
# 6127  1804.02.26.R          176.0          NaN         NaN
# 6128    1803.05.17          175.0          NaN         NaN
# 6129    1803.03.00          174.0          NaN         NaN
# 6130  1802.04.13.R          173.0          NaN         NaN
# 6131  1801.12.18.R          172.0          NaN         NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# - **Mostrad 2 filas al azar del dataframe**

# %%
df.sample(2)
# Out:
#        Case Number    Year        Type Country           Area  \
# 5221  1922.09.21.R  1922.0     Boating     USA  Massachusetts
# 4302    1955.02.10  1955.0  Unprovoked     USA     California
#
#                            Location      Activity  \
# 5221                         Nahant       Fishing
# 4302  Trinidad Bay, Humboldt County  Scuba diving
#
#                                              Name Sex   Age  ...  \
# 5221  boat, occupants:  Mr. Goslin & 4 passengers  NaN  NaN  ...
# 4302                                   John Adams    M  NaN  ...
#
#                                                Species   \
# 5221                               "A pack of 6 sharks"
# 4302  Leopard shark, 3' Triakis semifasciata, identi...
#
#                                  Investigator or Source  \
# 5221                       L. Schultz & M. Malin, p.554
# 4302  J. DeWitt (1955); V.M. Coppleson (1962), p.255...
#
#                             pdf  \
# 5221  1922.09.21-GoslinBoat.pdf
# 4302       1955.02.10-Adams.pdf
#
#                                            href formula  \
# 5221  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4302  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 5221  http://sharkattackfile.net/spreadsheets/pdf_di...  1922.09.21.R
# 4302  http://sharkattackfile.net/spreadsheets/pdf_di...    1955.02.10
#
#      Case Number.2 original order  Unnamed: 22 Unnamed: 23
# 5221  1922.09.21.R         1082.0          NaN         NaN
# 4302    1955.02.10         2001.0          NaN         NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# - **¿Cuál es el nombre de las columnas del DataFrame?**

# %%
df.columns
# Out:
# Index(['Case Number', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# - **¿Cuáles son los principales estádisticos del dataframe? Mostrad por separado las variables categóricas y las variables numéricas.**

# %%
df.describe() # Nos devuelve los principales estaditicos
# Out:
#               Year  original order
# count  6114.000000     6114.000000
# mean   1968.831207     3237.445044
# std      43.745920     1769.652633
# min    1801.000000      172.000000
# 25%    1946.000000     1706.250000
# 50%    1980.000000     3236.500000
# 75%    2005.000000     4768.750000
# max    2018.000000     6303.000000

# %%
df.info() #nos da la información sobre DT
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6114 entries, 0 to 6131
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6113 non-null   object
#  1   Year                    6114 non-null   float64
#  2   Type                    6110 non-null   object
#  3   Country                 6074 non-null   object
#  4   Area                    5706 non-null   object
#  5   Location                5626 non-null   object
#  6   Activity                5603 non-null   object
#  7   Name                    5914 non-null   object
#  8   Sex                     5564 non-null   object
#  9   Age                     3448 non-null   object
#  10  Time                    2934 non-null   object
#  11  Species                 3409 non-null   object
#  12  Investigator or Source  6098 non-null   object
#  13  pdf                     6114 non-null   object
#  14  href formula            6113 non-null   object
#  15  href                    6114 non-null   object
#  16  Case Number.1           6114 non-null   object
#  17  Case Number.2           6114 non-null   object
#  18  original order          6114 non-null   float64
#  19  Unnamed: 22             1 non-null      object
#  20  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(19)
# memory usage: 1.0+ MB

# %% [markdown]
# - **¿Cuál es el porcentaje de valores nulos en cada columna?**

# %%
porcentaje_nulls = ((df.isnull().sum() / len(df))*100).sort_values(ascending = False)
porcentaje_nulls
# Out:
# Unnamed: 22               99.983644
# Unnamed: 23               99.967288
# Time                      52.011776
# Species                   44.242722
# Age                       43.604841
# Sex                        8.995747
# Activity                   8.357867
# Location                   7.981681
# Area                       6.673209
# Name                       3.271181
# Country                    0.654236
# Investigator or Source     0.261694
# Type                       0.065424
# href formula               0.016356
# Case Number                0.016356
# Year                       0.000000
# pdf                        0.000000
# href                       0.000000
# Case Number.1              0.000000
# Case Number.2              0.000000
# original order             0.000000
# dtype: float64

# %% [markdown]
# - **Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.**

# %%
repeticion_valores = df["Year"].value_counts()
repeticion_valores

df.columns

dic = {}

for i in df.columns:
    df[i].value_counts()
    dic[i] = df[i].value_counts()

# %% [markdown]
# - **Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.**

# %%
columnas_nuevas = {col :  col.lower() for col in df.columns}
df.rename(columns = columnas_nuevas, inplace= True)
df.head(2)
# Out:
#   case number    year        type country        area  \
# 0  2018.06.25  2018.0     Boating     USA  California
# 1  2018.06.18  2018.0  Unprovoked     USA     Georgia
#
#                          location  activity             name sex  age  ...  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  57  ...
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  11  ...
#
#       species           investigator or source                     pdf  \
# 0  White shark                R. Collier, GSAF    2018.06.25-Wolfe.pdf
# 1          NaN  K.McMurray, TrackingSharks.com  2018.06.18-McNeely.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
#
#   case number.2 original order  unnamed: 22 unnamed: 23
# 0    2018.06.25         6303.0          NaN         NaN
# 1    2018.06.18         6302.0          NaN         NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# - **Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.**

# %%
df.drop(["unnamed: 22","unnamed: 23", "case number.1", "case number.2", "original order", "investigator or source", "pdf", "href formula"], axis = 'columns', inplace=True)
df.columns
# Out:
# Index(['case number', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex ', 'age', 'time', 'species ', 'href'],
#       dtype='object')

# %% [markdown]
# - **Establece la columna Case Number como índice del dataframe.**

# %%
df.set_index("case number")
df= df.set_index("case number")
df.head()
# Out:
#                year        type    country             area  \
# case number
# 2018.06.25   2018.0     Boating        USA       California
# 2018.06.18   2018.0  Unprovoked        USA          Georgia
# 2018.06.09   2018.0     Invalid        USA           Hawaii
# 2018.06.08   2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04   2018.0    Provoked     MEXICO           Colima
#
#                                    location     activity             name  \
# case number
# 2018.06.25      Oceanside, San Diego County     Paddling      Julie Wolfe
# 2018.06.18   St. Simon Island, Glynn County     Standing  Adyson McNeely
# 2018.06.09                     Habush, Oahu      Surfing      John Denges
# 2018.06.08               Arrawarra Headland      Surfing             male
# 2018.06.04                         La Ticla  Free diving   Gustavo Ramos
#
#             sex   age           time         species   \
# case number
# 2018.06.25     F   57          18h00      White shark
# 2018.06.18     F   11  14h00  -15h00              NaN
# 2018.06.09     M   48          07h45              NaN
# 2018.06.08     M  NaN            NaN        2 m shark
# 2018.06.04     M  NaN            NaN  Tiger shark, 3m
#
#                                                           href
# case number
# 2018.06.25   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.18   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.09   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.08   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.04   http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# **3. Guarda el csv que no tiene esas columnas para seguir usándolo mañana.**

# %%
df.to_csv("attack2.csv")
